# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('census.csv')

# %%
data
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# 0           4779736            4780127          4785161  ...
# 1             54571              54571            54660  ...
# 2            182265             182265           183193  ...
# 3             27457              27457            27341  ...
# 4             22915              22919            22861  ...
# ...             ...                ...              ...  ...
# 3188          43806              43806            43593  ...
# 3189          21294              21294            21297  ...
# 3190          21118              21118            21102  ...
# 3191           8533               8533             8545  ...
# 3192           7208               7208             7181  ...
#
#       RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0             0.002295         -0.193196          0.381066          0.582002
# 1             7.242091         -2.915927         -3.012349          2.265971
# 2            14.832960         17.647293         21.845705         19.243287
# 3            -4.728132         -2.500690         -7.056824         -3.904217
# 4            -5.527043         -5.068871         -6.201001         -0.177537
# ...                ...               ...               ...               ...
# 3188          1.072643         16.243199         -5.339774        -14.252889
# 3189         -1.589565          0.972695         19.525929         14.143021
# 3190        -17.755986         -4.916350         -6.902954        -14.215862
# 3191        -11.637475         -0.827815         -2.013502        -17.781491
# 3192        -11.752361         -8.040059         12.372583          1.533635
#
#       RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  \
# 0            -0.467369     1.030015     0.826644     1.383282     1.724718
# 1            -2.530799     7.606016    -2.626146    -2.722002     2.592270
# 2            17.197872    15.844176    18.559627    22.727626    20.317142
# 3           -10.543299    -4.874741    -2.758113    -7.167664    -3.978583
# 4             0.177258    -5.088389    -4.363636    -5.403729     0.754533
# ...                ...          ...          ...          ...          ...
# 3188        -14.248864     1.255221    16.243199    -5.295460   -14.075283
# 3189         -0.564849     0.654527     2.408578    21.160658    16.308671
# 3190        -12.127022   -18.136812    -5.536861    -7.521840   -14.740608
# 3191          1.682288   -11.990126    -1.182592    -2.250385   -18.020168
# 3192          6.935294   -12.032179    -8.040059    12.372583     1.533635
#
#       RNETMIG2015
# 0        0.712594
# 1       -2.187333
# 2       18.293499
# 3      -10.543299
# 4        1.107861
# ...           ...
# 3188   -14.070195
# 3189     1.520747
# 3190   -12.606351
# 3191     1.441961
# 3192     6.935294
#
# [3193 rows x 100 columns]

# %%
df= data.copy()

# %%
df.shape
# Out:
# (3193, 100)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3193 entries, 0 to 3192
# Data columns (total 100 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SUMLEV                 3193 non-null   int64
#  1   REGION                 3193 non-null   int64
#  2   DIVISION               3193 non-null   int64
#  3   STATE                  3193 non-null   int64
#  4   COUNTY                 3193 non-null   int64
#  5   STNAME                 3193 non-null   object
#  6   CTYNAME                3193 non-null   object
#  7   CENSUS2010POP          3193 non-null   int64
#  8   ESTIMATESBASE2010      3193 non-null   int64
#  9   POPESTIMATE2010        3193 non-null   int64
#  10  POPESTIMATE2011        3193 non-null   int64
#  11  POPESTIMATE2012        3193 non-null   int64
#  12  POPESTIMATE2013        3193 non-null   int64
#  13  POPESTIMATE2014        3193 non-null   int64
#  14  POPESTIMATE2015        3193 non-null   int64
#  15  NPOPCHG_2010           3193 non-null   int64
#  16  NPOPCHG_2011           3193 non-null   int64
#  17  NPOPCHG_2012           3193 non-null   int64
#  18  NPOPCHG_2013           3193 non-null   int64
#  19  NPOPCHG_2014           3193 non-null   int64
#  20  NPOPCHG_2015           3193 non-null   int64
#  21  BIRTHS2010             3193 non-null   int64
#  22  BIRTHS2011             3193 non-null   int64
#  23  BIRTHS2012             3193 non-null   int64
#  24  BIRTHS2013             3193 non-null   int64
#  25  BIRTHS2014             3193 non-null   int64
#  26  BIRTHS2015             3193 non-null   int64
#  27  DEATHS2010             3193 non-null   int64
#  28  DEATHS2011             3193 non-null   int64
#  29  DEATHS2012             3193 non-null   int64
#  30  DEATHS2013             3193 non-null   int64
#  31  DEATHS2014             3193 non-null   int64
#  32  DEATHS2015             3193 non-null   int64
#  33  NATURALINC2010         3193 non-null   int64
#  34  NATURALINC2011         3193 non-null   int64
#  35  NATURALINC2012         3193 non-null   int64
#  36  NATURALINC2013         3193 non-null   int64
#  37  NATURALINC2014         3193 non-null   int64
#  38  NATURALINC2015         3193 non-null   int64
#  39  INTERNATIONALMIG2010   3193 non-null   int64
#  40  INTERNATIONALMIG2011   3193 non-null   int64
#  41  INTERNATIONALMIG2012   3193 non-null   int64
#  42  INTERNATIONALMIG2013   3193 non-null   int64
#  43  INTERNATIONALMIG2014   3193 non-null   int64
#  44  INTERNATIONALMIG2015   3193 non-null   int64
#  45  DOMESTICMIG2010        3193 non-null   int64
#  46  DOMESTICMIG2011        3193 non-null   int64
#  47  DOMESTICMIG2012        3193 non-null   int64
#  48  DOMESTICMIG2013        3193 non-null   int64
#  49  DOMESTICMIG2014        3193 non-null   int64
#  50  DOMESTICMIG2015        3193 non-null   int64
#  51  NETMIG2010             3193 non-null   int64
#  52  NETMIG2011             3193 non-null   int64
#  53  NETMIG2012             3193 non-null   int64
#  54  NETMIG2013             3193 non-null   int64
#  55  NETMIG2014             3193 non-null   int64
#  56  NETMIG2015             3193 non-null   int64
#  57  RESIDUAL2010           3193 non-null   int64
#  58  RESIDUAL2011           3193 non-null   int64
#  59  RESIDUAL2012           3193 non-null   int64
#  60  RESIDUAL2013           3193 non-null   int64
#  61  RESIDUAL2014           3193 non-null   int64
#  62  RESIDUAL2015           3193 non-null   int64
#  63  GQESTIMATESBASE2010    3193 non-null   int64
#  64  GQESTIMATES2010        3193 non-null   int64
#  65  GQESTIMATES2011        3193 non-null   int64
#  66  GQESTIMATES2012        3193 non-null   int64
#  67  GQESTIMATES2013        3193 non-null   int64
#  68  GQESTIMATES2014        3193 non-null   int64
#  69  GQESTIMATES2015        3193 non-null   int64
#  70  RBIRTH2011             3193 non-null   float64
#  71  RBIRTH2012             3193 non-null   float64
#  72  RBIRTH2013             3193 non-null   float64
#  73  RBIRTH2014             3193 non-null   float64
#  74  RBIRTH2015             3193 non-null   float64
#  75  RDEATH2011             3193 non-null   float64
#  76  RDEATH2012             3193 non-null   float64
#  77  RDEATH2013             3193 non-null   float64
#  78  RDEATH2014             3193 non-null   float64
#  79  RDEATH2015             3193 non-null   float64
#  80  RNATURALINC2011        3193 non-null   float64
#  81  RNATURALINC2012        3193 non-null   float64
#  82  RNATURALINC2013        3193 non-null   float64
#  83  RNATURALINC2014        3193 non-null   float64
#  84  RNATURALINC2015        3193 non-null   float64
#  85  RINTERNATIONALMIG2011  3193 non-null   float64
#  86  RINTERNATIONALMIG2012  3193 non-null   float64
#  87  RINTERNATIONALMIG2013  3193 non-null   float64
#  88  RINTERNATIONALMIG2014  3193 non-null   float64
#  89  RINTERNATIONALMIG2015  3193 non-null   float64
#  90  RDOMESTICMIG2011       3193 non-null   float64
#  91  RDOMESTICMIG2012       3193 non-null   float64
#  92  RDOMESTICMIG2013       3193 non-null   float64
#  93  RDOMESTICMIG2014       3193 non-null   float64
#  94  RDOMESTICMIG2015       3193 non-null   float64
#  95  RNETMIG2011            3193 non-null   float64
#  96  RNETMIG2012            3193 non-null   float64
#  97  RNETMIG2013            3193 non-null   float64
#  98  RNETMIG2014            3193 non-null   float64
#  99  RNETMIG2015            3193 non-null   float64
# dtypes: float64(30), int64(68), object(2)
# memory usage: 2.4+ MB

# %%
# check for missing values
df.isnull().sum()
# Out:
# SUMLEV         0
# REGION         0
# DIVISION       0
# STATE          0
# COUNTY         0
#               ..
# RNETMIG2011    0
# RNETMIG2012    0
# RNETMIG2013    0
# RNETMIG2014    0
# RNETMIG2015    0
# Length: 100, dtype: int64

# %%
#visualizing missing values using heat map
plt.figure(figsize =(12,16))
sns.heatmap(df.isnull(),cbar = True, cmap = 'cool')
plt.title('visualization of missing values')
plt.show()

# %%
columns =list(df.columns)

# %%
columns
# Out:
# ['SUMLEV',
#  'REGION',
#  'DIVISION',
#  'STATE',
#  'COUNTY',
#  'STNAME',
#  'CTYNAME',
#  'CENSUS2010POP',
#  'ESTIMATESBASE2010',
#  'POPESTIMATE2010',
#  'POPESTIMATE2011',
#  'POPESTIMATE2012',
#  'POPESTIMATE2013',
#  'POPESTIMATE2014',
#  'POPESTIMATE2015',
#  'NPOPCHG_2010',
#  'NPOPCHG_2011',
#  'NPOPCHG_2012',
#  'NPOPCHG_2013',
#  'NPOPCHG_2014',
#  'NPOPCHG_2015',
#  'BIRTHS2010',
#  'BIRTHS2011',
#  'BIRTHS2012',
#  'BIRTHS2013',
#  'BIRTHS2014',
#  'BIRTHS2015',
#  'DEATHS2010',
#  'DEATHS2011',
#  'DEATHS2012',
#  'DEATHS2013',
#  'DEATHS2014',
#  'DEATHS2015',
#  'NATURALINC2010',
#  'NATURALINC2011',
#  'NATURALINC2012',
#  'NATURALINC2013',
#  'NATURALINC2014',
#  'NATURALINC2015',
#  'INTERNATIONALMIG2010',
#  'INTERNATIONALMIG2011',
#  'INTERNATIONALMIG2012',
#  'INTERNATIONALMIG2013',
#  'INTERNATIONALMIG2014',
#  'INTERNATIONALMIG2015',
#  'DOMESTICMIG2010',
#  'DOMESTICMIG2011',
#  'DOMESTICMIG2012',
#  'DOMESTICMIG2013',
#  'DOMESTICMIG2014',
#  'DOMESTICMIG2015',
#  'NETMIG2010',
#  'NETMIG2011',
#  'NETMIG2012',
#  'NETMIG2013',
#  'NETMIG2014',
#  'NETMIG2015',
#  'RESIDUAL2010',
#  'RESIDUAL2011',
#  'RESIDUAL2012',
#  'RESIDUAL2013',
#  'RESIDUAL2014',
#  'RESIDUAL2015',
#  'GQESTIMATESBASE2010',
#  'GQESTIMATES2010',
#  'GQESTIMATES2011',
#  'GQESTIMATES2012',
#  'GQESTIMATES2013',
#  'GQESTIMATES2014',
#  'GQESTIMATES2015',
#  'RBIRTH2011',
#  'RBIRTH2012',
#  'RBIRTH2013',
#  'RBIRTH2014',
#  'RBIRTH2015',
#  'RDEATH2011',
#  'RDEATH2012',
#  'RDEATH2013',
#  'RDEATH2014',
#  'RDEATH2015',
#  'RNATURALINC2011',
#  'RNATURALINC2012',
#  'RNATURALINC2013',
#  'RNATURALINC2014',
#  'RNATURALINC2015',
#  'RINTERNATIONALMIG2011',
#  'RINTERNATIONALMIG2012',
#  'RINTERNATIONALMIG2013',
#  'RINTERNATIONALMIG2014',
#  'RINTERNATIONALMIG2015',
#  'RDOMESTICMIG2011',
#  'RDOMESTICMIG2012',
#  'RDOMESTICMIG2013',
#  'RDOMESTICMIG2014',
#  'RDOMESTICMIG2015',
#  'RNETMIG2011',
#  'RNETMIG2012',
#  'RNETMIG2013',
#  'RNETMIG2014',
#  'RNETMIG2015']

# %%
df.describe()
# Out:
#             SUMLEV       REGION     DIVISION        STATE       COUNTY  \
# count  3193.000000  3193.000000  3193.000000  3193.000000  3193.000000
# mean     49.840276     2.668650     5.191356    30.259004   101.918572
# std       1.253884     0.807513     1.973991    15.153897   107.626583
# min      40.000000     1.000000     1.000000     1.000000     0.000000
# 25%      50.000000     2.000000     4.000000    18.000000    33.000000
# 50%      50.000000     3.000000     5.000000    29.000000    77.000000
# 75%      50.000000     3.000000     7.000000    45.000000   133.000000
# max      50.000000     4.000000     9.000000    56.000000   840.000000
#
#        CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# count   3.193000e+03       3.193000e+03     3.193000e+03     3.193000e+03
# mean    1.933871e+05       1.933969e+05     1.937657e+05     1.952514e+05
# std     1.176201e+06       1.176244e+06     1.178710e+06     1.189648e+06
# min     8.200000e+01       8.200000e+01     8.300000e+01     9.000000e+01
# 25%     1.129900e+04       1.129900e+04     1.127500e+04     1.127700e+04
# 50%     2.642400e+04       2.644600e+04     2.646700e+04     2.641700e+04
# 75%     7.140400e+04       7.149100e+04     7.172100e+04     7.238700e+04
# max     3.725396e+07       3.725450e+07     3.733408e+07     3.770003e+07
#
#        POPESTIMATE2012  ...  RDOMESTICMIG2011  RDOMESTICMIG2012  \
# count     3.193000e+03  ...       3193.000000       3193.000000
# mean      1.967445e+05  ...         -1.639167         -2.528381
# std       1.200508e+06  ...         10.407267         11.871798
# min       8.100000e+01  ...       -128.205128       -147.727273
# 25%       1.119500e+04  ...         -6.153101         -7.561799
# 50%       2.636200e+04  ...         -1.544618         -2.549859
# 75%       7.249600e+04  ...          2.901204          2.626611
# max       3.805606e+07  ...        101.123596        119.193807
#
#        RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  RNETMIG2011  \
# count       3193.000000       3193.000000       3193.000000  3193.000000
# mean          -1.288083         -2.271925         -1.362607    -0.655205
# std           12.186844         11.440505         12.301558    10.613259
# min         -109.876862       -178.947368        -84.844838  -128.205128
# 25%           -6.323058         -7.357497         -6.696825    -5.354221
# 50%           -1.771445         -1.988101         -2.026566    -0.626174
# 75%            3.392786          3.333927          3.794291     4.062151
# max          239.130435        146.367943        281.407035   101.123596
#
#        RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# count  3193.000000  3193.000000  3193.000000  3193.000000
# mean     -1.445775    -0.200419    -1.038960    -0.096759
# std      12.228155    12.200064    11.471743    12.265772
# min    -147.727273  -102.988031  -178.947368   -62.322703
# 25%      -6.851764    -5.426357    -6.221820    -5.553088
# 50%      -1.537988    -0.788296    -0.911948    -0.872527
# 75%       3.962629     4.700873     4.580444     5.013928
# max     119.861185   239.130435   146.960126   281.407035
#
# [8 rows x 98 columns]

# %% [markdown]
# ## Which state has the most counties in it? (hint: consider the sumlevel key carefully! You'll need this forfuture questions too...)

# %%
# Filter out the rows with SUMLEV == 40
sdf = df[df['SUMLEV'] == 50]

# Group the dataframe by state name and count the number of counties
counties_by_state = sdf.groupby('STNAME')['COUNTY'].nunique()

# Find the state with the most counties
state_with_most_counties = counties_by_state.idxmax()

print(f"The state with the most counties is {state_with_most_counties}.")
# Out:
# The state with the most counties is Texas.

# %%
# Group the dataframe by state name and count the number of counties
counties_by_state = sdf.groupby('STNAME')['COUNTY'].nunique()

# Find the state with the most counties
state_with_most_counties = counties_by_state.idxmax()

# Plot the number of counties for the state with the most counties
counties_by_state.plot(kind='bar', y=state_with_most_counties, title='The number of counties for each State')

# Add the number of counties as text labels above the bars
for i, v in enumerate(counties_by_state):
    plt.text(i - 0.1, v + 0.5, str(v))

# Show the plot
plt.show()

# %% [markdown]
# ### Only looking at the three most populous counties for each state, what are the three most populous states (in order of highest population to lowest population)? Use CENSUS2010POP

# %%
# Sort the dataframe by state and population
vdf = sdf.sort_values(['STNAME', 'CENSUS2010POP'], ascending=[True, False])

# Group the dataframe by state and take the top 3 counties for each state
vdf = vdf.groupby('STNAME').head(3)

# Group the resulting dataframe by state and sum the population of the top 3 counties
vdf = vdf.groupby('STNAME').sum()

# Sort the resulting dataframe by population and take the top 3 states
vdf = vdf.sort_values('CENSUS2010POP', ascending=False).head(3)

# Plot the dataframe as a bar chart
vdf.plot(kind='bar', y='CENSUS2010POP', title='The three most populous states (in order of highest population to lowest population)')


# Show the plot
plt.show()

# %%
vdf
# Out:
#             SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME
# California     150      12        27     18     169
# Texas          150       9        21    144     753
# Illinois       150       6         9     51     171
#
#                                                     CTYNAME  CENSUS2010POP  \
# STNAME
# California  Los Angeles CountySan Diego CountyOrange County       15924150
# Texas              Harris CountyDallas CountyTarrant County        8269632
# Illinois                Cook CountyDuPage CountyLake County        6815061
#
#             ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  ...  \
# STNAME                                                           ...
# California           15924274         15948261         16094942  ...
# Texas                 8270250          8298179          8439027  ...
# Illinois              6815323          6821742          6841179  ...
#
#             RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  \
# STNAME
# California         -2.651916         -3.217407         -5.070710
# Texas               7.142972         14.863483          7.496872
# Illinois          -19.864534        -18.494617        -14.252015
#
#             RDOMESTICMIG2014  RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  \
# STNAME
# California         -7.111949        -12.065453    10.408013    10.545720
# Texas               9.559581          8.836789    20.398518    27.431740
# Illinois          -22.842075        -26.515534   -11.715929    -9.144169
#
#             RNETMIG2013  RNETMIG2014  RNETMIG2015
# STNAME
# California     9.005753     8.543736     3.920882
# Texas         21.195186    25.187793    24.341074
# Illinois      -4.775492   -12.003940   -15.246911
#
# [3 rows x 99 columns]

# %%
vdf[["COUNTY","CENSUS2010POP"]]
# Out:
#             COUNTY  CENSUS2010POP
# STNAME
# California     169       15924150
# Texas          753        8269632
# Illinois       171        6815061

# %% [markdown]
# ### Which region has the most division in it?

# %%
df['REGION']= df['REGION'].astype(str).replace('1',"Northeast", regex = True).replace("2",'Midwest',regex = True).replace("3",'South', regex = True).replace("4",'West', regex = True)

# %%
df['REGION']
# Out:
# 0       South
# 1       South
# 2       South
# 3       South
# 4       South
#         ...
# 3188     West
# 3189     West
# 3190     West
# 3191     West
# 3192     West
# Name: REGION, Length: 3193, dtype: object

# %%
# Filter out the rows with SUMLEV == 40
sldf = df[df['SUMLEV'] == 40]

# Group the dataframe by region and count the number of divisions
divisions_by_region = sldf.groupby('REGION')['DIVISION'].nunique()

# Plot the number of divisions for each region
divisions_by_region.plot(kind='bar', title='The number of divisions for each region')

# Show the plot
plt.show()

# %%
divisions_by_region
# Out:
# REGION
# Midwest      2
# Northeast    2
# South        3
# West         2
# Name: DIVISION, dtype: int64
